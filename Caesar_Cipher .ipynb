# %% [markdown]
# # Caesar Cipher

# %%
def decrypt_shift_cipher(ciphertext, key):
    plain_text = ""

    for char in ciphertext:
        if char == " ":
            plain_text += " "
            continue

        if char.isupper():
            # Shift within 'A'-'Z'
            plain_text += chr((ord(char) - 65 - key) % 26 + 65)
        elif char.islower():
            # Shift within 'a'-'z'
            plain_text += chr((ord(char) - 97 - key) % 26 + 97)
        else:
            # Keep punctuation/symbols unchanged
            plain_text += char

    return plain_text

# %%
def encrypt_shift_cipher(plaintext, key):
    cipher_text = ""

    for char in plaintext:
        if char == " ":
            cipher_text += " "
        elif char.isupper():
            # Shift within 'A'-'Z'
            cipher_text += chr((ord(char) - 65 + key) % 26 + 65)
        elif char.islower():
            # Shift within 'a'-'z'
            cipher_text += chr((ord(char) - 97 + key) % 26 + 97)
        else:
            # Keep punctuation/symbols unchanged
            cipher_text += char

    return cipher_text

# %%
#Encrypt the following plaintext, using the summation of last 2 digits of your ID as the key
plaintext="I am batman"
key=12
ciphertext = encrypt_shift_cipher(plaintext, key)
print(encrypt_shift_cipher(plaintext, key))
plaintext_2 = decrypt_shift_cipher(ciphertext, key)
print(plaintext_2)
# Out:
# U my nmfymz
# I am batman

# %%
ciphertext= "U my nmfymz"
plaintext_2 = decrypt_shift_cipher(ciphertext, key)
print(plaintext_2)
# Out:
# I am batman

# %%
#Decrypt the following text and find out the value of the key using the decrypt_shift_cipher() method. Hint: Use bruteforce
ciphertext = "Jhw wr wkh fkrssd"
#to do

for key in range(26):
    print(f"key={key}---{decrypt_shift_cipher(ciphertext, key)}")
# Out:
# key=0---Jhw wr wkh fkrssd
# key=1---Igv vq vjg ejqrrc
# key=2---Hfu up uif dipqqb
# key=3---Get to the choppa
# key=4---Fds sn sgd bgnooz
# key=5---Ecr rm rfc afmnny
# key=6---Dbq ql qeb zelmmx
# key=7---Cap pk pda ydkllw
# key=8---Bzo oj ocz xcjkkv
# key=9---Ayn ni nby wbijju
# key=10---Zxm mh max vahiit
# key=11---Ywl lg lzw uzghhs
# key=12---Xvk kf kyv tyfggr
# key=13---Wuj je jxu sxeffq
# key=14---Vti id iwt rwdeep
# key=15---Ush hc hvs qvcddo
# key=16---Trg gb gur pubccn
# key=17---Sqf fa ftq otabbm
# key=18---Rpe ez esp nszaal
# key=19---Qod dy dro mryzzk
# key=20---Pnc cx cqn lqxyyj
# key=21---Omb bw bpm kpwxxi
# key=22---Nla av aol jovwwh
# key=23---Mkz zu znk inuvvg
# key=24---Ljy yt ymj hmtuuf
# key=25---Kix xs xli glstte

# %%
#Test the obtained plaintext from upper block and generate all possible ciphertexts using the encrypt_shift_cipher() method.
plaintext = "Pdeo Ykza Nqjo Kj Lqna Dkla Wjz XnwyQ SeBe"

for key in range(26):
    print(f"key={key}---{encrypt_shift_cipher(plaintext, key)}")
#to do
# Out:
# key=0---Pdeo Ykza Nqjo Kj Lqna Dkla Wjz XnwyQ SeBe
# key=1---Qefp Zlab Orkp Lk Mrob Elmb Xka YoxzR TfCf
# key=2---Rfgq Ambc Pslq Ml Nspc Fmnc Ylb ZpyaS UgDg
# key=3---Sghr Bncd Qtmr Nm Otqd Gnod Zmc AqzbT VhEh
# key=4---This Code Runs On Pure Hope And BracU WiFi
# key=5---Uijt Dpef Svot Po Qvsf Ipqf Boe CsbdV XjGj
# key=6---Vjku Eqfg Twpu Qp Rwtg Jqrg Cpf DtceW YkHk
# key=7---Wklv Frgh Uxqv Rq Sxuh Krsh Dqg EudfX ZlIl
# key=8---Xlmw Gshi Vyrw Sr Tyvi Lsti Erh FvegY AmJm
# key=9---Ymnx Htij Wzsx Ts Uzwj Mtuj Fsi GwfhZ BnKn
# key=10---Znoy Iujk Xaty Ut Vaxk Nuvk Gtj HxgiA CoLo
# key=11---Aopz Jvkl Ybuz Vu Wbyl Ovwl Huk IyhjB DpMp
# key=12---Bpqa Kwlm Zcva Wv Xczm Pwxm Ivl JzikC EqNq
# key=13---Cqrb Lxmn Adwb Xw Ydan Qxyn Jwm KajlD FrOr
# key=14---Drsc Myno Bexc Yx Zebo Ryzo Kxn LbkmE GsPs
# key=15---Estd Nzop Cfyd Zy Afcp Szap Lyo MclnF HtQt
# key=16---Ftue Oapq Dgze Az Bgdq Tabq Mzp NdmoG IuRu
# key=17---Guvf Pbqr Ehaf Ba Cher Ubcr Naq OenpH JvSv
# key=18---Hvwg Qcrs Fibg Cb Difs Vcds Obr PfoqI KwTw
# key=19---Iwxh Rdst Gjch Dc Ejgt Wdet Pcs QgprJ LxUx
# key=20---Jxyi Setu Hkdi Ed Fkhu Xefu Qdt RhqsK MyVy
# key=21---Kyzj Tfuv Ilej Fe Gliv Yfgv Reu SirtL NzWz
# key=22---Lzak Ugvw Jmfk Gf Hmjw Zghw Sfv TjsuM OaXa
# key=23---Mabl Vhwx Kngl Hg Inkx Ahix Tgw UktvN PbYb
# key=24---Nbcm Wixy Lohm Ih Joly Bijy Uhx VluwO QcZc
# key=25---Ocdn Xjyz Mpin Ji Kpmz Cjkz Viy WmvxP RdAd

# %%
#Encrypt the following plaintext, using the summation of last 2 digits of your ID as the key
plaintext = "I am Ironman"
key = 12
#to do
print(encrypt_shift_cipher(plaintext, key))
# Out:
# U my Udazymz
