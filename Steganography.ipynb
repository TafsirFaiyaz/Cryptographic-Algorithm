# %%
from PIL import Image

# %%
def hide_message(image_path, message):
    img = Image.open(image_path)

    binary_message = ''.join(format(ord(i), '08b') for i in message)

    width, height = img.size

    max_message_length = (width * height) // 8

    if len(binary_message) > max_message_length:
        raise ValueError('Message too long to be hidden in the given image')

    new_img = Image.new(img.mode, img.size)

    message_index = 0

    # Loop through each pixel in the image - use nested loop where x represents width & y represents height
    # Get the RGB values of the current pixel, using img.getpixel()
    # unpack the result tuple to red, green & blue
    #todo
    for x in range(width):
        for y in range(height):

            # Get the RGB values of the current pixel
            pixel = img.getpixel((x, y))

            # Unpack the result tuple to red, green & blue
            # Note: This assumes an RGB image. If RGBA, we ignore alpha for hiding.
            red, green, blue = pixel[0], pixel[1], pixel[2]

            # Check if the message has been fully hidden
            if message_index == len(binary_message):
                new_img.putpixel((x, y), pixel)
                continue

            # Modify the least significant bit of each RGB value with the message bits
            red_binary = format(red, '08b')
            green_binary = format(green, '08b')
            blue_binary = format(blue, '08b')

            #update last value of red_binary and increment message_index (done for you)
            red_binary = red_binary[:-1] + binary_message[message_index]
            message_index += 1

            #check if message_index reached it's limit
            #if yes, set '0' as the last value of green and blue binary
            #else, update last value of green_binary and increment message_index
            #todo
            green_binary = green_binary[:-1] + binary_message[message_index]
            message_index += 1

            #check again if message_index reached it's limit
            #if yes, set '0' as the last value of blue binary
            #else, update the last value of blue_binary and increment message_index
            #todo
            blue_binary = blue_binary[:-1] + binary_message[message_index]
            message_index += 1

            #converting back to binary
            red = int(red_binary, 2)
            green = int(green_binary, 2)
            blue = int(blue_binary, 2)

            # Create a new pixel with the modified RGB values and add it to the new image
            new_pixel = (red, green, blue)
            new_img.putpixel((x, y), new_pixel)

    # Save the new image with the message hidden inside
    new_img.save('hidden.png')

# %%
hide_message("/content/Blue orchid.jpg", "Naruto[a] is a Japanese manga series written and illustrated by Masashi Kishimoto. It tells the story of Naruto Uzumaki, a young, socially isolated ninja who seeks recognition from his peers and dreams of becoming the Hokage, the leader of his village. The story is told in two parts: the first is set in Naruto's pre-teen years (volumes 1–27), and the second in his teens (volumes 28–72). The series is based on two one-shot manga by Kishimoto: Karakuri (1995), which earned Kishimoto an honorable mention in Shueisha's monthly Hop Step Award the following year, and Naruto (1997).")

# %%
def extract_message(image_path):
    # Open the image
    img = Image.open(image_path)

    # Get the size of the image
    width, height = img.size

    binary_message = ''
    # Loop through each pixel in the image - use nested loop where x represents width & y represents height
    #todo
    for x in range(width):
        for y in range(height):

            red, green, blue = img.getpixel((x, y))

            pixel = img.getpixel((x, y))
            red, green, blue = pixel

            red_binary = format(red, '08b')
            green_binary = format(green, '08b')
            blue_binary = format(blue, '08b')

            #concat last bit of every red_binary, green_binary & blue_binary to binary_message
            #todo
            binary_message += red_binary[-1]
            binary_message += green_binary[-1]
            binary_message += blue_binary[-1]

    # Convert the binary message to text (done for you)
    message = ''
    for i in range(0, len(binary_message), 8):
        message += chr(int(binary_message[i:i+8], 2))

    return message

# %%
extract_message("/content/hidden.png")
# Out:
# 'Naruto[a] is a Japanese manga series written and illustrated by Masashi Kishimoto. It tells the story of Naruto Uzumaki, a young, socially isolated ninja who seeks recognition from his peers and dreams of becoming the Hokage, the leader of his village. The story is told in two parts: the first is set in Naruto\'s pre-teen years (volumes 1\x80LÈÜ¤°\x81\x85¹\x90\x81Ñ¡\x94\x81Í\x95\x8d½¹\x90\x81¥¸\x81¡¥Ì\x81Ñ\x95\x95¹Ì\x80¡Ù½±Õµ\x95Ì\x80Èâ\x013s"\x92â\x05F\x86R\x076W&\x96W2\x06\x972\x06&\x176VB\x06öâ\x07Gvò\x06öæR×6\x86÷B\x06Ö\x16æv\x12\x06\'\x92\x04¶\x976\x86\x96Ö÷Fó¢\x04¶\x17&\x16·W&\x92\x02\x83\x13\x93\x93R\x92Â\x07v\x86\x966\x82\x06V\x17&æVB\x04¶\x976\x86\x96Ö÷Fò\x06\x16â\x06\x86öæ÷&\x16&ÆR\x06ÖVçF\x96öâ\x06\x96â\x056\x87VV\x976\x86\x12w2\x06ÖöçF\x86Ç\x92\x04\x86÷\x02\x057FW\x02\x04\x17v\x17&B\x07F\x86R\x06föÆÆ÷v\x96ær\x07\x96V\x17"Â\x06\x16æB\x04æ\x17\'WFò\x02\x83\x13\x93\x93r\x92ë\x7fÿÿÿÿÿä\x9fÿí¿ÿÒI$\x9bm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Û}³¤o\x0e?\x1bm\x89$\x92I$\x92I$\x92I=\x80\x00\x00\x00\t?þ\x1bm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûr¤¤@\x7fñü\x01¿ü\x7fö8âv;c\x95ª7\x0e%+m@\x7fÉ$\x92vÀ$\x80\x00\x7fðÿ\x8e\x80à\x0bm;e\x8eÛ\x13\x8eµ¶ÛØèÜÜ\x93Õ\x8eHÛm¶Ü\x8e8ã\x8dÇ\x1c\x91½\x8e$\x99$\x92KR§\x16ÛÇaR\x92KPü\x07\x1b\x1fñ¶&LK«\x92ÉÍÅÎ\x8bm¸8\x93¶;m±\'lIÀ\x0fÿ\x00\x04\x91;m±\x00\x0bmI$\x96?ßÿürNmÄ\xadJÜN29ú\'\x12a\nÄ£rU\x1e\x02¢q\x1f\x8d¶Jÿûj\x89!;ý\x8e\'m¶Ø\x91ÿü\x00\x00\x1fð?\x1fòI$\x9d¶ÛbI$\x92I$\x9d¶Ûm¶Ûm¶ßý¶Ûm¶Ûm¶Ûm¶À\x00\x00\t-¶Ûoÿÿÿÿÿð\x00\x00\x0fÿÿÿÿÿù$\x92I$\x92I$\x92I$\x89 \x00\x1fô\x92I$\x92I$\x90\x1fÿÿößÿÿÿÿÿù?ÿÿÿÿd\x92I&Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ýri\x1b\x83\x8fÆÛbI$\x92I$\x92I$\x92Oà\x00\x00\x00\x02OÿöÛm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ü©(\x90\x1fóÿ\x00\x0e?\x1fòN;bq\'\x14ªq¼v©$\x95ü\x0fÉ$\x9d\x80\t \x00\x03ò\x07ã\xa0?\x01$vØ\x9d¶Ç\x13\x8drI\x0e9ÈH8õ\\n9\x1br7$qÈÛ\x8dÉ$oÿÿý¹$\x96¤±&I\x0e;ô\x94\x8dZ\x07\x01¸À\x00|caÏÎ<ícq}©ÄïùÇlI;lIØ\x92p\x03ÿÀ\x01,NÛl@\x02ÛRI%\x8fÿÿÿ\x1c\x93±m+RµZª¶EQ$c¿©$ß/ð\x12§oÀà\x00\x07n7hâM± \x9cNÇm±$\x7fÿ\x00\x00\x00ÿ\x81ÿ\x00\x92I\'m¶Ø\x92I$\x92I\'m¶Ûm¶Û\x12Oÿm¶Ûm¶Ûm¶Ûm°\x00\x00\x02H\x00\x00\x03ÿÿÿÿÿü\x00\x00\x03ÿÿÿÿÿþI$\x92I$\x92I$\x92I"H\x00\x07ý$\x92I$\x92I$\x84ÿÿý·ÿÿÿÿÿÿÿÿÿÿÿÙ$\x92I¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûmº\x84\x92Fà\x1fñ¶Ø\x92I$\x92I\'ÿÿü\x93ø\x00\x00\x00\x03ÿ\x1bl¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm·-\x1eßÀ\x03ñø\x1f\x81À\x00\x92q;bv:¥s\x93c\xadI%o\x03ÿÿä\x00\x02K\x80\x00\x00ð8è\x0fÀ¸âN$\x92I\'bkq½±l\x93±=&Ûq·#\x92Fãr6Ü\x8e7\x1b\x1f\x8e\x07m´\x92J³±\x8e|qã¥\x1cJ\x81À\x00w\x89ãm¿\x1f\x1dÐ\x8eHI\x04*N8þ6Ø\x92IÛ\x12v$\x92\x00ÿð\x00I\x13¶Û\x10\x00¶Ô\x92Ib\x7fÿÿÇÄ\x9cIJÔ\xadJ¥Rn+¶\x04íêI|Èµ-\x87à\x0f\x89ÿ\x9dRH~ãd\x92v$\x9d¶ÛbI\x1fÿÀ\x00\x00\x00ÿñÿÛm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûl\x00Ûm¶Ûm¶$\x92I$\x93ÿÿÿmÿÿÿÿÿÿÿÿÿÿÿÿ\x00\x00\x00\x00\x00\x00m¶Ûm¶Ûm¶Ûm¶Ýÿþ\x00I$\x92I$\x92I!$ÿÿm\x00\x00\x00\x00\x00\x00ÿÿÿÿÿÿ¶ÛmI$\x92I$\x92I$\x92I$\x92I$\x92I$\x92I$\x92I$\x92\x91%$µ¹Çÿí¶$\x92I$\x92Iÿÿÿ$ÿ\x80\x00\x00\x00ÿÈÛ$¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶ÛmËÿ\x02Oÿ\x00~\x07\x00p\x00$\x9cqûbqµ\\\\ª¬II+\x7f¶Û\x7fÿûmÿ\x80\x00ß\x81Å\x03ð\x0eØ\x92v$\x92N8\x95[lìdÄ\x1d·I¶Üm¶ärI#q·\x1b\x929\x07ü~$¶¥U\x93\x1cd\x83bø\x16Öê\xa0\x0fÇ\x1dÉ\x07Ø\x83¦Ç¨N;m·µ9\x89Ó\x8d¶$\x92vÄ\x9d\x89$\x80\t\'\x13\x92V\xad¶Ä\x00-µ$\x92H\x92\x7fÿñö\'bRµ+RU+cu\x02@Ä¹dq\x80¦ØqÎÃ\x8fÎU\x0e9Û3¶\'lvÛbvØ\x92Gÿð\x00\x00\x00\x07ÿÿöÛm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Û\x7föÛm¶Ûm\x89$\x92I$ÿÿÿÛ\x7fÿÿÿÿÿÿÿÿÿÿÿÀ\x00\x00\x00\x00\x00\x1bm¶Ûm¶Ûm¶Ûm¶ÿÿ\x80\x12I$\x92I$\x92II?ÿÛ@\x00\x00?ÿÿÿÿù?ÿÛm¶ÛRI$\x92I$\x92I$\x92I$\x92I$\x92I$\x92I$\x92I$\x92II-®qÿûlI$\x92I$\x92\x7fÿÿÉ\'í\x80\x00\x00?òI\t%¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûp\x7fä\x9fÿÀ\x03\x8fÀ\x03\x81É\'c\x87\'c\x82¨\x9d\x95WbM©$\x89.Ûm¶Û\x7fÿÿÈ\x1f\x8fGày$mÍ¶Ä\x9cvÅXÞÛw±\x04\x92\x12\x92Hãn9$rHÛ\x926ä\x8eAÿ\x16«mª¦Ù%\x89\'9À8ª:¨ãþ?q±Æý\x93\x89®8Ü\x9c\x0e/\xadã\x8cülI$\x9d±\'bI \x02NÄ\x90\x07©-±\x00\x0bmI$\x92$\x9fÿü}\x89Û\x14\xadJÔ\x95©)#·\x1fñÒ6\x03\x02¼x@}Ç\x1f\x9e\x17\x1b\x1d\x89;\x1d¶Äí¶Û\x12I$\x91ÿü\x00\x00\x00\x0fÿÿý¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶Ûm¶À\r¶Ûm¶ÛbI$\x92I?ÿÿößÿÿÿÿÿÿÿÿÿÿÿð\x00\x00\x00\x00\x00\x06Ûm¶Ûm¶Ûm¶Ûm¿ÿà\x04\x92I$\x92I$\x92ROÿöÐ\x00\x00\x0fÿÿÿÿò@\x92I+m¶Ô\x ...
